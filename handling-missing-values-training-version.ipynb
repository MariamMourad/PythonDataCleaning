# %% [markdown]
# ## Take a first look at the data

# %%
# modules we'll use
import pandas as pd
import numpy as np

# read in all our data
data = pd.read_csv("Building_Permits.csv")
# Out:
# C:\Users\lenovo.DESKTOP-72JGRGQ.000\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# we can see missing data
data.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
# get the number of missing data points per column
missing_values_count = data.isnull().sum()

missing_values_count[0:-1]
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
# how many total missing values do we have?
total_cells = np.product(data.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 26.26002315058403

# %%
# remove the columns that has more than 50% missing values
data1 = data.dropna(axis=1, thresh=int(0.5*len(data)))
data1.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# ...

# %% [markdown]
# How much data did we lost by removing that columns?

# %%
# get the number of missing data points per column
missing_values_count1 = data1.isnull().sum()

# how many total missing values do we have?
total_cells1 = np.product(data1.shape)
total_missing1 = missing_values_count1.sum()

# percent of data that is missing
percent_missing1 = (total_missing1/total_cells1) * 100
print(percent_missing - percent_missing1)
# Out:
# 17.123995587220826

# %% [markdown]
# It's not acceptable to remove mre than 5% of the data ..
# There is many ways to fill the null values the most simple way is by filling out the quantitative values with it's mean
# and the categorical values by it's mode ..
# But for the seek of the training I will follow the Kaggle courses' tutorial and replace missing values with whatever value comes directly after it in the same column & fill the rest with 0.

# %%
data2 = data

# replace all NA's the value that comes directly after it in the same column, 
# then replace all the remaining na's with 0
data2.fillna(method='bfill', axis=0).fillna(0)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...
